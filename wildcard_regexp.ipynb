# %%
import pandas as pd
import re

# %%
df = pd.read_csv('data_pokemon.csv')

# %% [markdown]
# # Wildcards

# %%
df.loc[df['Name'].str.contains('Mega')].head(3)
# Out:
#    #                       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 3  3      VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 7  6  CharizardMega Charizard X   Fire  Dragon  78     130      111      130
# 8  6  CharizardMega Charizard Y   Fire  Flying  78     104       78      159
#
#    Sp. Def  Speed  Generation  Legendary
# 3      120     80           1      False
# 7       85    100           1      False
# 8      115    100           1      False

# %% [markdown]
# # Regular Expression

# %%
df.loc[df['Name'].str.contains('sh$', regex=True)].head(5)
# Out:
#        #       Name  Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 33    28  Sandslash  Ground     NaN  75     100      110       45       55
# 48    43     Oddish   Grass  Poison  45      50       55       75       65
# 84    78   Rapidash    Fire     NaN  65     100       70       80       80
# 227  211   Qwilfish   Water  Poison  65      95       75       55       55
# 309  285  Shroomish   Grass     NaN  60      40       60       40       60
#
#      Speed  Generation  Legendary
# 33      65           1      False
# 48      30           1      False
# 84     105           1      False
# 227     85           2      False
# 309     35           3      False

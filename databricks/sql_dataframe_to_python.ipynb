# %%
import pandas as pd
import numpy as np

# %%
# %sql
SELECT created_dttm, tc_order_id, do_status 
FROM non_published_domain.na_node_connect.orders o
WHERE created_dttm >= '2026-06-25'
LIMIT 10
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df1 = _sqldf.toPandas()  # Converts Spark DataFrame to Pandas

# %%
df1
# Out:
#          created_dttm tc_order_id do_status
# 0 2026-06-25 08:38:40  0878140315       170
# 1 2026-06-25 08:41:38   632393692       170
# 2 2026-06-25 09:44:09   632394499       140
# 3 2026-06-25 09:10:49  0878194914       140
# 4 2026-06-25 09:48:31  0878134821       140
# 5 2026-06-25 09:52:06   632394649       140
# 6 2026-06-25 09:44:10   632394333       140
# 7 2026-06-25 08:22:41  0877463871       150
# 8 2026-06-25 08:41:37   632393717       150
# 9 2026-06-25 09:26:38  0877988264       140
